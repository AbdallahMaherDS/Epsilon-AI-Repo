# %% [markdown]
# # Preprocessing Data

# %% [markdown]
# ## Importing Helper Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importing Data

# %%
df=pd.read_csv('Global EV Data 2024.csv')
df
# Out:
#         region          category           parameter    mode  \
# 0      Austria        Historical            EV stock    Cars
# 1      Austria        Historical      EV stock share    Cars
# 2      Belgium        Historical            EV stock   Buses
# 3      Belgium        Historical            EV sales    Vans
# 4      Belgium        Historical            EV stock    Vans
# ...        ...               ...                 ...     ...
# 12649    World  Projection-STEPS      EV sales share    Cars
# 12650    World  Projection-STEPS      EV stock share    Cars
# 12651    World    Projection-APS  EV charging points      EV
# 12652    World    Projection-APS  EV charging points      EV
# 12653    World  Projection-STEPS      EV stock share  Trucks
#
#                     powertrain  year             unit            value  \
# 0                          BEV  2010         Vehicles              350
# 1                           EV  2010          percent  789.999.961.853
# 2                          BEV  2010         Vehicles                3
# 3                          BEV  2010         Vehicles                7
# 4                          BEV  2010         Vehicles               62
# ...                        ...   ...              ...              ...
# 12649                       EV  2035          percent               55
# 12650                       EV  2035          percent               31
# 12651  Publicly available fast  2035  charging points          9400000
# 12652  Publicly available slow  2035  charging points         15000000
# 12653                       EV  2035          percent                9
#
#                percentage
# 0               35000,00%
# 1      78999996185300,00%
# 2                 300,00%
# 3                 700,00%
# 4                6200,00%
# ...                   ...
# 12649            5500,00%
# 12650            3100,00%
# 12651       940000000,00%
# 12652      1500000000,00%
# 12653             900,00%
#
# [12654 rows x 9 columns]

# %% [markdown]
# ## Cleaning Data

# %%
#Capitalize columns names
df.columns=df.columns.str.capitalize()
df
# Out:
#         Region          Category           Parameter    Mode  \
# 0      Austria        Historical            EV stock    Cars
# 1      Austria        Historical      EV stock share    Cars
# 2      Belgium        Historical            EV stock   Buses
# 3      Belgium        Historical            EV sales    Vans
# 4      Belgium        Historical            EV stock    Vans
# ...        ...               ...                 ...     ...
# 12649    World  Projection-STEPS      EV sales share    Cars
# 12650    World  Projection-STEPS      EV stock share    Cars
# 12651    World    Projection-APS  EV charging points      EV
# 12652    World    Projection-APS  EV charging points      EV
# 12653    World  Projection-STEPS      EV stock share  Trucks
#
#                     Powertrain  Year             Unit            Value  \
# 0                          BEV  2010         Vehicles              350
# 1                           EV  2010          percent  789.999.961.853
# 2                          BEV  2010         Vehicles                3
# 3                          BEV  2010         Vehicles                7
# 4                          BEV  2010         Vehicles               62
# ...                        ...   ...              ...              ...
# 12649                       EV  2035          percent               55
# 12650                       EV  2035          percent               31
# 12651  Publicly available fast  2035  charging points          9400000
# 12652  Publicly available slow  2035  charging points         15000000
# 12653                       EV  2035          percent                9
#
#                Percentage
# 0               35000,00%
# 1      78999996185300,00%
# 2                 300,00%
# 3                 700,00%
# 4                6200,00%
# ...                   ...
# 12649            5500,00%
# 12650            3100,00%
# 12651       940000000,00%
# 12652      1500000000,00%
# 12653             900,00%
#
# [12654 rows x 9 columns]

# %%
#capitalize units names
df['Unit'] = df['Unit'].str.capitalize()
df
# Out:
#         Region          Category           Parameter    Mode  \
# 0      Austria        Historical            EV stock    Cars
# 1      Austria        Historical      EV stock share    Cars
# 2      Belgium        Historical            EV stock   Buses
# 3      Belgium        Historical            EV sales    Vans
# 4      Belgium        Historical            EV stock    Vans
# ...        ...               ...                 ...     ...
# 12649    World  Projection-STEPS      EV sales share    Cars
# 12650    World  Projection-STEPS      EV stock share    Cars
# 12651    World    Projection-APS  EV charging points      EV
# 12652    World    Projection-APS  EV charging points      EV
# 12653    World  Projection-STEPS      EV stock share  Trucks
#
#                     Powertrain  Year             Unit            Value  \
# 0                          BEV  2010         Vehicles              350
# 1                           EV  2010          Percent  789.999.961.853
# 2                          BEV  2010         Vehicles                3
# 3                          BEV  2010         Vehicles                7
# 4                          BEV  2010         Vehicles               62
# ...                        ...   ...              ...              ...
# 12649                       EV  2035          Percent               55
# 12650                       EV  2035          Percent               31
# 12651  Publicly available fast  2035  Charging points          9400000
# 12652  Publicly available slow  2035  Charging points         15000000
# 12653                       EV  2035          Percent                9
#
#                Percentage
# 0               35000,00%
# 1      78999996185300,00%
# 2                 300,00%
# 3                 700,00%
# 4                6200,00%
# ...                   ...
# 12649            5500,00%
# 12650            3100,00%
# 12651       940000000,00%
# 12652      1500000000,00%
# 12653             900,00%
#
# [12654 rows x 9 columns]

# %%
# Drop 'Percentage' column
df.drop(['Percentage'], axis=1, inplace=True)
df
# Out:
#         Region          Category           Parameter    Mode  \
# 0      Austria        Historical            EV stock    Cars
# 1      Austria        Historical      EV stock share    Cars
# 2      Belgium        Historical            EV stock   Buses
# 3      Belgium        Historical            EV sales    Vans
# 4      Belgium        Historical            EV stock    Vans
# ...        ...               ...                 ...     ...
# 12649    World  Projection-STEPS      EV sales share    Cars
# 12650    World  Projection-STEPS      EV stock share    Cars
# 12651    World    Projection-APS  EV charging points      EV
# 12652    World    Projection-APS  EV charging points      EV
# 12653    World  Projection-STEPS      EV stock share  Trucks
#
#                     Powertrain  Year             Unit            Value
# 0                          BEV  2010         Vehicles              350
# 1                           EV  2010          Percent  789.999.961.853
# 2                          BEV  2010         Vehicles                3
# 3                          BEV  2010         Vehicles                7
# 4                          BEV  2010         Vehicles               62
# ...                        ...   ...              ...              ...
# 12649                       EV  2035          Percent               55
# 12650                       EV  2035          Percent               31
# 12651  Publicly available fast  2035  Charging points          9400000
# 12652  Publicly available slow  2035  Charging points         15000000
# 12653                       EV  2035          Percent                9
#
# [12654 rows x 8 columns]

# %%
# Drop rows where 'Parameter' column has the value 'Oil displacement, million lge'
df.drop(df[df['Parameter']=='Oil displacement, million lge'].index,inplace=True)
df
# Out:
#         Region          Category           Parameter    Mode  \
# 0      Austria        Historical            EV stock    Cars
# 1      Austria        Historical      EV stock share    Cars
# 2      Belgium        Historical            EV stock   Buses
# 3      Belgium        Historical            EV sales    Vans
# 4      Belgium        Historical            EV stock    Vans
# ...        ...               ...                 ...     ...
# 12649    World  Projection-STEPS      EV sales share    Cars
# 12650    World  Projection-STEPS      EV stock share    Cars
# 12651    World    Projection-APS  EV charging points      EV
# 12652    World    Projection-APS  EV charging points      EV
# 12653    World  Projection-STEPS      EV stock share  Trucks
#
#                     Powertrain  Year             Unit            Value
# 0                          BEV  2010         Vehicles              350
# 1                           EV  2010          Percent  789.999.961.853
# 2                          BEV  2010         Vehicles                3
# 3                          BEV  2010         Vehicles                7
# 4                          BEV  2010         Vehicles               62
# ...                        ...   ...              ...              ...
# 12649                       EV  2035          Percent               55
# 12650                       EV  2035          Percent               31
# 12651  Publicly available fast  2035  Charging points          9400000
# 12652  Publicly available slow  2035  Charging points         15000000
# 12653                       EV  2035          Percent                9
#
# [12068 rows x 8 columns]

# %%
# Drop rows where 'Parameter' column is 'Oil displacement Mbd'
df.drop(df[df['Parameter']=='Oil displacement Mbd'].index,inplace=True)
df
# Out:
#         Region          Category           Parameter    Mode  \
# 0      Austria        Historical            EV stock    Cars
# 1      Austria        Historical      EV stock share    Cars
# 2      Belgium        Historical            EV stock   Buses
# 3      Belgium        Historical            EV sales    Vans
# 4      Belgium        Historical            EV stock    Vans
# ...        ...               ...                 ...     ...
# 12649    World  Projection-STEPS      EV sales share    Cars
# 12650    World  Projection-STEPS      EV stock share    Cars
# 12651    World    Projection-APS  EV charging points      EV
# 12652    World    Projection-APS  EV charging points      EV
# 12653    World  Projection-STEPS      EV stock share  Trucks
#
#                     Powertrain  Year             Unit            Value
# 0                          BEV  2010         Vehicles              350
# 1                           EV  2010          Percent  789.999.961.853
# 2                          BEV  2010         Vehicles                3
# 3                          BEV  2010         Vehicles                7
# 4                          BEV  2010         Vehicles               62
# ...                        ...   ...              ...              ...
# 12649                       EV  2035          Percent               55
# 12650                       EV  2035          Percent               31
# 12651  Publicly available fast  2035  Charging points          9400000
# 12652  Publicly available slow  2035  Charging points         15000000
# 12653                       EV  2035          Percent                9
#
# [11482 rows x 8 columns]

# %%
# Modify the 'Unit' column based on the 'Parameter' column
df['Unit'] = df.apply(lambda row: 'Shares' if row['Parameter'] == 'EV stock' else row['Unit'], axis=1)
df[df['Parameter']=='EV stock']
# Out:
#         Region          Category Parameter   Mode Powertrain  Year    Unit  \
# 0      Austria        Historical  EV stock   Cars        BEV  2010  Shares
# 2      Belgium        Historical  EV stock  Buses        BEV  2010  Shares
# 4      Belgium        Historical  EV stock   Vans        BEV  2010  Shares
# 6      Belgium        Historical  EV stock   Cars        BEV  2010  Shares
# 9      Belgium        Historical  EV stock   Cars       FCEV  2010  Shares
# ...        ...               ...       ...    ...        ...   ...     ...
# 12631    World  Projection-STEPS  EV stock   Vans       FCEV  2035  Shares
# 12632    World  Projection-STEPS  EV stock   Vans       PHEV  2035  Shares
# 12633    World  Projection-STEPS  EV stock   Cars        BEV  2035  Shares
# 12634    World  Projection-STEPS  EV stock   Cars       FCEV  2035  Shares
# 12635    World  Projection-STEPS  EV stock   Cars       PHEV  2035  Shares
#
#            Value
# 0            350
# 2              3
# 4             62
# 6             61
# 9              1
# ...          ...
# 12631     980000
# 12632    1400000
# 12633  390000000
# 12634    1200000
# 12635   89000000
#
# [3470 rows x 8 columns]

# %%
# Convert the 'Value' column to numeric, coercing errors to NaN
df['Value']=pd.to_numeric(df['Value'],errors='coerce')
df
# Out:
#         Region          Category           Parameter    Mode  \
# 0      Austria        Historical            EV stock    Cars
# 1      Austria        Historical      EV stock share    Cars
# 2      Belgium        Historical            EV stock   Buses
# 3      Belgium        Historical            EV sales    Vans
# 4      Belgium        Historical            EV stock    Vans
# ...        ...               ...                 ...     ...
# 12649    World  Projection-STEPS      EV sales share    Cars
# 12650    World  Projection-STEPS      EV stock share    Cars
# 12651    World    Projection-APS  EV charging points      EV
# 12652    World    Projection-APS  EV charging points      EV
# 12653    World  Projection-STEPS      EV stock share  Trucks
#
#                     Powertrain  Year             Unit       Value
# 0                          BEV  2010           Shares       350.0
# 1                           EV  2010          Percent         NaN
# 2                          BEV  2010           Shares         3.0
# 3                          BEV  2010         Vehicles         7.0
# 4                          BEV  2010           Shares        62.0
# ...                        ...   ...              ...         ...
# 12649                       EV  2035          Percent        55.0
# 12650                       EV  2035          Percent        31.0
# 12651  Publicly available fast  2035  Charging points   9400000.0
# 12652  Publicly available slow  2035  Charging points  15000000.0
# 12653                       EV  2035          Percent         9.0
#
# [11482 rows x 8 columns]

# %%
# Drop rows with missing values
df.dropna(inplace=True)
df
# Out:
#         Region          Category           Parameter    Mode  \
# 0      Austria        Historical            EV stock    Cars
# 2      Belgium        Historical            EV stock   Buses
# 3      Belgium        Historical            EV sales    Vans
# 4      Belgium        Historical            EV stock    Vans
# 5      Belgium        Historical            EV sales    Cars
# ...        ...               ...                 ...     ...
# 12649    World  Projection-STEPS      EV sales share    Cars
# 12650    World  Projection-STEPS      EV stock share    Cars
# 12651    World    Projection-APS  EV charging points      EV
# 12652    World    Projection-APS  EV charging points      EV
# 12653    World  Projection-STEPS      EV stock share  Trucks
#
#                     Powertrain  Year             Unit       Value
# 0                          BEV  2010           Shares       350.0
# 2                          BEV  2010           Shares         3.0
# 3                          BEV  2010         Vehicles         7.0
# 4                          BEV  2010           Shares        62.0
# 5                          BEV  2010         Vehicles        48.0
# ...                        ...   ...              ...         ...
# 12649                       EV  2035          Percent        55.0
# 12650                       EV  2035          Percent        31.0
# 12651  Publicly available fast  2035  Charging points   9400000.0
# 12652  Publicly available slow  2035  Charging points  15000000.0
# 12653                       EV  2035          Percent         9.0
#
# [8895 rows x 8 columns]

# %%
# Reset the index
df.reset_index(drop=True, inplace=True)
df
# Out:
#        Region          Category           Parameter    Mode  \
# 0     Austria        Historical            EV stock    Cars
# 1     Belgium        Historical            EV stock   Buses
# 2     Belgium        Historical            EV sales    Vans
# 3     Belgium        Historical            EV stock    Vans
# 4     Belgium        Historical            EV sales    Cars
# ...       ...               ...                 ...     ...
# 8890    World  Projection-STEPS      EV sales share    Cars
# 8891    World  Projection-STEPS      EV stock share    Cars
# 8892    World    Projection-APS  EV charging points      EV
# 8893    World    Projection-APS  EV charging points      EV
# 8894    World  Projection-STEPS      EV stock share  Trucks
#
#                    Powertrain  Year             Unit       Value
# 0                         BEV  2010           Shares       350.0
# 1                         BEV  2010           Shares         3.0
# 2                         BEV  2010         Vehicles         7.0
# 3                         BEV  2010           Shares        62.0
# 4                         BEV  2010         Vehicles        48.0
# ...                       ...   ...              ...         ...
# 8890                       EV  2035          Percent        55.0
# 8891                       EV  2035          Percent        31.0
# 8892  Publicly available fast  2035  Charging points   9400000.0
# 8893  Publicly available slow  2035  Charging points  15000000.0
# 8894                       EV  2035          Percent         9.0
#
# [8895 rows x 8 columns]
